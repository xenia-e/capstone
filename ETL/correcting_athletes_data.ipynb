# %%
import pandas as pd

# %%
path = "./olypic_games_clean.csv"
df = pd.read_csv(path)

# %%
path = "athletes_data_clean.csv"
df2 = pd.read_csv(path)
df2
# Out:
#             ID                      Name Sex  Age  Height  Weight  \
# 0            1                 A Dijiang   M   24   180.0    80.0
# 1            2                  A Lamusi   M   23   170.0    60.0
# 2            5  Christine Jacoba Aaftink   F   21   185.0    82.0
# 3            5  Christine Jacoba Aaftink   F   21   185.0    82.0
# 4            5  Christine Jacoba Aaftink   F   25   185.0    82.0
# ...        ...                       ...  ..  ...     ...     ...
# 205874  135569                Andrzej ya   M   29   179.0    89.0
# 205875  135570                  Piotr ya   M   27   176.0    59.0
# 205876  135570                  Piotr ya   M   27   176.0    59.0
# 205877  135571        Tomasz Ireneusz ya   M   30   185.0    96.0
# 205878  135571        Tomasz Ireneusz ya   M   34   185.0    96.0
#
#                Team  NOC        Games          Sport  \
# 0             China  CHN  1992 Summer     Basketball
# 1             China  CHN  2012 Summer           Judo
# ...

# %%
df2["Medal"].isnull().sum()
# Out:
# 175785

# %%
df2["Medal"].fillna("none", inplace = True)

# %%
df2.head()
# Out:
#    ID                      Name Sex  Age  Height  Weight         Team  NOC  \
# 0   1                 A Dijiang   M   24   180.0    80.0        China  CHN
# 1   2                  A Lamusi   M   23   170.0    60.0        China  CHN
# 2   5  Christine Jacoba Aaftink   F   21   185.0    82.0  Netherlands  NED
# 3   5  Christine Jacoba Aaftink   F   21   185.0    82.0  Netherlands  NED
# 4   5  Christine Jacoba Aaftink   F   25   185.0    82.0  Netherlands  NED
#
#          Games          Sport                               Event Medal
# 0  1992 Summer     Basketball         Basketball Men's Basketball  none
# 1  2012 Summer           Judo        Judo Men's Extra-Lightweight  none
# 2  1988 Winter  Speed Skating    Speed Skating Women's 500 metres  none
# 3  1988 Winter  Speed Skating  Speed Skating Women's 1,000 metres  none
# 4  1992 Winter  Speed Skating    Speed Skating Women's 500 metres  none

# %%
### remove the comma's that kept giving the parser in pgadmin errors
df2["Event"] = df2["Event"].apply(lambda x: x.replace(',',''))

# %%
### remove the quotes that kept giving the parser in pgadmin errors
df2["Name"] = df2["Name"].apply(lambda x: x.replace('"',''))
df2
# Out:
#             ID                      Name Sex  Age  Height  Weight  \
# 0            1                 A Dijiang   M   24   180.0    80.0
# 1            2                  A Lamusi   M   23   170.0    60.0
# 2            5  Christine Jacoba Aaftink   F   21   185.0    82.0
# 3            5  Christine Jacoba Aaftink   F   21   185.0    82.0
# 4            5  Christine Jacoba Aaftink   F   25   185.0    82.0
# ...        ...                       ...  ..  ...     ...     ...
# 205874  135569                Andrzej ya   M   29   179.0    89.0
# 205875  135570                  Piotr ya   M   27   176.0    59.0
# 205876  135570                  Piotr ya   M   27   176.0    59.0
# 205877  135571        Tomasz Ireneusz ya   M   30   185.0    96.0
# 205878  135571        Tomasz Ireneusz ya   M   34   185.0    96.0
#
#                Team  NOC        Games          Sport  \
# 0             China  CHN  1992 Summer     Basketball
# 1             China  CHN  2012 Summer           Judo
# ...

# %%
df3 = df2.applymap(",", "")
df3.head()
# Out:
#    ID                      Name Sex  Age  Height  Weight         Team  NOC  \
# 0   1                 A Dijiang   M   24   180.0    80.0        China  CHN
# 1   2                  A Lamusi   M   23   170.0    60.0        China  CHN
# 2   5  Christine Jacoba Aaftink   F   21   185.0    82.0  Netherlands  NED
# 3   5  Christine Jacoba Aaftink   F   21   185.0    82.0  Netherlands  NED
# 4   5  Christine Jacoba Aaftink   F   25   185.0    82.0  Netherlands  NED
#
#          Games          Sport                               Event Medal
# 0  1992 Summer     Basketball         Basketball Men's Basketball  none
# 1  2012 Summer           Judo        Judo Men's Extra-Lightweight  none
# 2  1988 Winter  Speed Skating    Speed Skating Women's 500 metres  none
# 3  1988 Winter  Speed Skating  Speed Skating Women's 1,000 metres  none
# 4  1992 Winter  Speed Skating    Speed Skating Women's 500 metres  none

# %%
df2["Medal"].isnull().values.any()
# Out:
# False

# %%
df2.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age         int64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
df2.to_csv('athlete_clean_data_2.csv', index=False)

# %%
df2.to_json('athlete_clean_data.json', orient="records")
